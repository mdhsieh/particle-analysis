# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install keras==2.2.5

# !pip install keras==2.3.0 
# !pip install tensorflow==1.15.0rc2

# !pip install keras==2.1.0

# %%
# tf 1.15.2
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 1.15.2

# %%
# try fix AttributeError: 'str' object has no attribute 'decode'
# !pip install h5py==2.10.0

# %%
import os
root = "/content/drive/MyDrive/data/summer-project/Mask_RCNN/samples/nucleus/"
os.chdir(root)
# !pwd

# import nucleus
# Out:
# /content/drive/MyDrive/data/summer-project/Mask_RCNN/samples/nucleus

# %%
# import shutil

# import os, shutil

# root_src_dir = '../../datasets/nucleus/stage1_train/'    # Path/Location of the source directory
# root_dst_dir = '../../simple-500-images-dataset/nucleus/stage1_train/'  # Path to the destination folder

# count = 0
# # Copy the first 500 folders [folder, subfolder image, subfolder mask] 
# # from datasets/nucleus/stage1_train/
# # to make a new, smaller dataset faster to train. 
# for src_dir, dirs, files in os.walk(root_src_dir):
#     # 1500/3 = 500 folders
#     if count > 1500:
#         print("done")
#         break
#     dst_dir = src_dir.replace(root_src_dir, root_dst_dir, 1)
#     if not os.path.exists(dst_dir):
#         os.makedirs(dst_dir)
#     print(dst_dir)
#     for file_ in files:
#         src_file = os.path.join(src_dir, file_)
#         dst_file = os.path.join(dst_dir, file_)
#         if os.path.exists(dst_file):
#             os.remove(dst_file)
#         shutil.copy(src_file, dst_dir)
#     count += 1

# %%
# Unzip new data folder containing the first 300 folders
# from datasets/nucleus/stage1_train/
# !unzip "../../simple-300-images-dataset"

# %%
# !ls ../../../Mask_RCNN/
# !zip -r "../../../Mask_RCNN.zip" ../../../Mask_RCNN/
# Out:
#   adding: ../../../Mask_RCNN/ (stored 0%)
#   adding: ../../../Mask_RCNN/LICENSE (deflated 41%)
#   adding: ../../../Mask_RCNN/MANIFEST.in (deflated 19%)
#   adding: ../../../Mask_RCNN/README.md (deflated 59%)
#   adding: ../../../Mask_RCNN/assets/ (stored 0%)
#   adding: ../../../Mask_RCNN/assets/4k_video.gif (deflated 0%)
#   adding: ../../../Mask_RCNN/assets/balloon_color_splash.gif (deflated 1%)
#   adding: ../../../Mask_RCNN/assets/detection_activations.png (deflated 0%)
#   adding: ../../../Mask_RCNN/assets/detection_anchors.png (deflated 1%)
#   adding: ../../../Mask_RCNN/assets/detection_final.png (deflated 0%)
#   adding: ../../../Mask_RCNN/assets/detection_histograms.png (deflated 4%)
#   adding: ../../../Mask_RCNN/assets/detection_masks.png (deflated 11%)
#   adding: ../../../Mask_RCNN/assets/detection_refinement.png (deflated 1%)
#   adding: ../../../Mask_RCNN/assets/detection_tensorboard.png (deflated 5%)
#   adding: ../../../Mask_RCNN/assets/images_to_osm.png (deflated 0%)
#   adding: ../../../Mask_RCNN/assets/mapping_challenge.png (deflated 0%)
#   adding: ../../../Mask_RCNN/assets/nucleus_segmentation.png (deflated 0%)
#   adding: ../../../Mask_RCNN/assets/project_3dbuildings.png (deflated 0%)
#   adding: ../../../Mask_RCNN/assets/project_grass_gis.png (deflated 0%)
#   adding: ../../../Mask_RCNN/assets/project_ice_wedge_polygons.png (deflated 0%)
#   adding: ../../../Mask_RCNN/assets/project_shiny1.jpg (deflated 1%)
#   adding: ../../../Mask_RCNN/assets/project_usiigaci1.gif (deflated 2%)
#   adding: ../../../Mask_RCNN/assets/project_usiigaci2.gif (deflated 1%)
#   adding: ../../../Mask_RCNN/assets/street.png (deflated 0%)
#   adding: ../../../Mask_RCNN/images/ (stored 0%)
#   adding: ../../../Mask_RCNN/images/1045023827_4ec3e8ba5c_z.jpg (deflated 1%)
#   adding: ../../../Mask_RCNN/images/12283150_12d37e6389_z.jpg (deflated 0%)
#   adding: ../../../Mask_RCNN/images/2383514521_1fc8d7b0de_z.jpg (deflated 0%)
#   adding: ../../../Mask_RCNN/images/2502287818_41e4b0c4fb_z.jpg (deflated 0%)
#   adding: ../../../Mask_RCNN/images/2516944023_d00345997d_z.jpg (deflated 0%)
#   adding: ../../../Mask_RCNN/images/25691390_f9944f61b5_z.jpg (deflated 0%)
#   adding: ../../../Mask_RCNN/images/262985539_1709e54576_z.jpg (deflated 0%)
#   adding: ../../../Mask_RCNN/images/3132016470_c27baa00e8_z.jpg (deflated 0%)
#   adding: ../../../Mask_RCNN/images/3627527276_6fe8cd9bfe_z.jpg (deflated 0%)
#   adding: ../../../Mask_RCNN/images/3651581213_f81963d1dd_z.jpg (deflated 2%)
#   adding: ../../../Mask_RCNN/images/3800883468_12af3c0b50_z.jpg (deflated 0%)
#   adding: ../../../Mask_RCNN/images/3862500489_6fd195d183_z.jpg (deflated 0%)
#   adding: ../../../Mask_RCNN/images/3878153025_8fde829928_z.jpg (deflated 0%)
#   adding: ../../../Mask_RCNN/images/4410436637_7b0ca36ee7_z.jpg (deflated 6%)
#   adding: ../../../Mask_RCNN/images/4782628554_668bc31826_z.jpg (deflated 3%)
#   adding: ../../../Mask_RCNN/images/5951960966_d4e1cda5d0_z.jpg (deflated 5%)
#   adding: ../../../Mask_RCNN/images/6584515005_fce9cec486_z.jpg (deflated 0%)
#   adding: ../../../Mask_RCNN/images/6821351586_59aa0dc110_z.jpg (deflated 0%)
#   adding: ../../../Mask_RCNN/images/7581246086_cf7bbb7255_z.jpg (deflated 0%)
#   adding: ../../../Mask_RCNN/images/7933423348_c30bd9bd4e_z.jpg (deflated 0%)
#   adding: ../../../Mask_RCNN/images/8053677163_d4c8f416be_z.jpg (deflated 0%)
#   adding: ../../../Mask_RCNN/images/8239308689_efa6c11b08_z.jpg (deflated 0%)
#   adding: ../../../Mask_RCNN/images/8433365521_9252889f9a_z.jpg (deflated 0%)
#   adding: ../../../Mask_RCNN/images/8512296263_5fc5458e20_z.jpg (deflated 0%)
#   adding: ../../../Mask_RCNN/images/8699757338_c3941051b6_z.jpg (deflated 0%)
#   adding: ../../../Mask_RCNN/images/8734543718_37f6b8bd45_z.jpg (deflated 0%)
#   adding: ../../../Mask_RCNN/images/8829708882_48f263491e_z.jpg (deflated 0%)
#   adding: ../../../Mask_RCNN/images/9118579087_f9ffa19e63_z.jpg (deflated 0%)
#   adding: ../../../Mask_RCNN/images/9247489789_132c0d534a_z.jpg (deflated 0%)
#   adding: ../../../Mask_RCNN/mrcnn/ (stored 0%)
#   adding: ../../../Mask_RCNN/mrcnn/__init__.py (stored 0%)
#   adding: ../../../Mask_RCNN/mrcnn/config.py (deflated 59%)
#   adding: ../../../Mask_RCNN/mrcnn/parallel_model.py (deflated 63%)
#   adding: ../../../Mask_RCNN/mrcnn/utils.py (deflated 70%)
#   adding: ../../../Mask_RCNN/mrcnn/visualize.py (deflated 70%)
#   adding: ../../../Mask_RCNN/mrcnn/__pycache__/ (stored 0%)
#   adding: ../../../Mask_RCNN/mrcnn/__pycache__/__init__.cpython-37.pyc (deflated 20%)
#   adding: ../../../Mask_RCNN/mrcnn/__pycache__/utils.cpython-37.pyc (deflated 56%)
#   adding: ../../../Mask_RCNN/mrcnn/__pycache__/visualize.cpython-37.pyc (deflated 47%)
#   adding: ../../../Mask_RCNN/mrcnn/__pycache__/config.cpython-37.pyc (deflated 37%)
#   adding: ../../../Mask_RCNN/mrcnn/__pycache__/model.cpython-37.pyc (deflated 59%)
#   adding: ../../../Mask_RCNN/mrcnn/model.py (deflated 75%)
#   adding: ../../../Mask_RCNN/requirements.txt (deflated 10%)
#   adding: ../../../Mask_RCNN/samples/ (stored 0%)
#   adding: ../../../Mask_RCNN/samples/balloon/ (stored 0%)
#   adding: ../../../Mask_RCNN/samples/balloon/README.md (deflated 55%)
#   adding: ../../../Mask_RCNN/samples/balloon/balloon.py (deflated 68%)
#   adding: ../../../Mask_RCNN/samples/balloon/inspect_balloon_data.ipynb (deflated 25%)
#   adding: ../../../Mask_RCNN/samples/balloon/inspect_balloon_model.ipynb (deflated 25%)
#   adding: ../../../Mask_RCNN/samples/coco/ (stored 0%)
#   adding: ../../../Mask_RCNN/samples/coco/coco.py (deflated 72%)
#   adding: ../../../Mask_RCNN/samples/coco/inspect_data.ipynb (deflated 25%)
#   adding: ../../../Mask_RCNN/samples/coco/inspect_model.ipynb (deflated 25%)
#   adding: ../../../Mask_RCNN/samples/coco/inspect_weights.ipynb (deflated 38%)
#   adding: ../../../Mask_RCNN/samples/coco/__pycache__/ (stored 0%)
#   adding: ../../../Mask_RCNN/samples/coco/__pycache__/coco.cpython-37.pyc (deflated 50%)
#   adding: ../../../Mask_RCNN/samples/shapes/ (stored 0%)
#   adding: ../../../Mask_RCNN/samples/shapes/shapes.py (deflated 65%)
#   adding: ../../../Mask_RCNN/samples/shapes/train_shapes.ipynb (deflated 49%)
#   adding: ../../../Mask_RCNN/samples/demo.ipynb (deflated 24%)
#   adding: ../../../Mask_RCNN/samples/nucleus/ (stored 0%)
#   adding: ../../../Mask_RCNN/samples/nucleus/README.md (deflated 56%)
#   adding: ../../../Mask_RCNN/samples/nucleus/inspect_nucleus_data.ipynb (deflated 26%)
#   adding: ../../../Mask_RCNN/samples/nucleus/inspect_nucleus_model.ipynb (deflated 25%)
#   adding: ../../../Mask_RCNN/samples/nucleus/__pycache__/ (stored 0%)
#   adding: ../../../Mask_RCNN/samples/nucleus/__pycache__/nucleus.cpython-37.pyc (deflated 42%)
#   adding: ../../../Mask_RCNN/samples/nucleus/nucleus.py (deflated 63%)
#   adding: ../../../Mask_RCNN/setup.cfg (deflated 21%)
#   adding: ../../../Mask_RCNN/setup.py (deflated 58%)

# %%
# create data folder with only 4 image subfolders to check mask r-cnn can finish training
# %mkdir ../../simple-dataset
# 1st set of 4 stage1_train
# %cp -r ../../datasets/nucleus/stage1_train/0a7d30b252359a10fd298b638b90cb9ada3acced4e0c0e5a3692013f432ee4e9 ../../simple-dataset
# %cp -r ../../datasets/nucleus/stage1_train/0acd2c223d300ea55d0546797713851e818e5c697d073b7f4091b96ce0f3d2fe ../../simple-dataset
# %cp -r ../../datasets/nucleus/stage1_train/00ae65c1c6631ae6f2be1a449902976e6eb8483bf6b0740d00530220832c6d3e ../../simple-dataset
# %cp -r ../../datasets/nucleus/stage1_train/0b0d577159f0d6c266f360f7b8dfde46e16fa665138bf577ec3c6f9c70c0cd1e ../../simple-dataset

# 1st 4 validation
# %cp -r ../../datasets/nucleus/stage1_train/0c2550a23b8a0f29a7575de8c61690d3c31bc897dd5ba66caec201d201a278c2 ../../simple-dataset
# %cp -r ../../datasets/nucleus/stage1_train
../../simple-dataset
# %cp -r ../../datasets/nucleus/stage1_train/1c8b905c9519061d6d091e702b45274f4485c80dcf7fb1491e6b2723f5002180 ../../simple-dataset
# %cp -r ../../datasets/nucleus/stage1_train/1c681dfa5cf7e413305d2e90ee47553a46e29cce4f6ed034c8297e511714f867 ../../simple-dataset

# # 8th set of 4
# %cp -r ../../datasets/nucleus/stage1_train/1d02c4b5921e916b9ddfb2f741fd6cf8d0e571ad51eb20e021c826b5fb87350e ../../simple-dataset
# %cp -r ../../datasets/nucleus/stage1_train/1d4a5e729bb96b08370789cad0791f6e52ce0ffe1fcc97a04046420b43c851dd ../../simple-dataset
# %cp -r ../../datasets/nucleus/stage1_train/1d5f4717e179a03675a5aac3fc1c862fb442ddc3e373923016fd6b1430da889b ../../simple-dataset
# %cp -r ../../datasets/nucleus/stage1_train/01d44a26f6680c42ba94c9bc6339228579a95d0e2695b149b7cc0c9592b21baf ../../simple-dataset

# # 9th set of 4
# %cp -r ../../datasets/nucleus/stage1_train/1db1cddf28e305c9478519cfac144eee2242183fe59061f1f15487e925e8f5b5 ../../simple-dataset
# %cp -r ../../datasets/nucleus/stage1_train/1e61ecf354cb93a62a9561db87a53985fb54e001444f98112ed0fc623fad793e ../../simple-dataset
# ###%cp -r ../../datasets/nucleus/stage1_train/1e488c42eb1a54a3e8412b1f12cde530f950f238d71078f2ede6a85a02168e1f ../../simple-dataset
# %cp -r ../../datasets/nucleus/stage1_train/1e8408fbb1619e7a0bcdd0bcd21fae57e7cb1f297d4c79787a9d0f5695d77073 ../../simple-dataset

# # 10th set of 4
# %cp -r ../../datasets/nucleus/stage1_train/1ec74a26e772966df764e063f1391109a60d803cff9d15680093641ed691bf72 ../../simple-dataset
# %cp -r ../../datasets/nucleus/stage1_train/1ee4a111f0e0bb9b001121b94ff98ca736fad03797b25285fe33a47046b3e4b0 ../../simple-dataset
# %cp -r ../../datasets/nucleus/stage1_train/1f6b7cead15344593b32d5f2345fc26713dc74d9b31306c824209d67da401fd8 ../../simple-dataset
# %cp -r ../../datasets/nucleus/stage1_train/1f9e429c12f4477221b5b855a5f494fda2ef6d064ff75b061ffaf093e91758c5 ../../simple-dataset

# # 11th set of 4
# %cp -r ../../datasets/nucleus/stage1_train/1f0008060150b5b93084ae2e4dabd160ab80a95ce8071a321b80ec4e33b58aca ../../simple-dataset
# %cp -r ../../datasets/nucleus/stage1_train/2a1a294e21d76efd0399e4eb321b45f44f7510911acd92c988480195c5b4c812 ../../simple-dataset
# %cp -r ../../datasets/nucleus/stage1_train/2a2032c4ed78f3fc64de7e5efd0bec26a81680b07404eaa54a1744b7ab3f8365 ../../simple-dataset
# %cp -r ../../datasets/nucleus/stage1_train/2ab91a4408860ae8339689ed9f87aa9359de1bdd4ca5c2eab7fff7724dbd6707 ../../simple-dataset

# # 12th set of 4
# %cp -r ../../datasets/nucleus/stage1_train/2abc40c118bc7303592c8bb95a80361e27560854b8971ab34dcf91966575b1f2 ../../simple-dataset
# %cp -r ../../datasets/nucleus/stage1_train/2ad489c11ed8b77a9d8a2339ac64ffc38e79281c03a2507db4688fd3186c0fe5 ../../simple-dataset
# %cp -r ../../datasets/nucleus/stage1_train/2b50b1e3fa5c5aa39bc84ebfaea9961b7199c4d2488ae0b48d0b3459807d59d2 ../../simple-dataset
# %cp -r ../../datasets/nucleus/stage1_train/2bf594e9d06f78b4b79d7ffb395497a0a91126b6b0d710d7a9cee21f5c3bd177 ../../simple-dataset

# %%
# !python nucleus.py train --dataset=../../datasets/nucleus/ --subset=train --weights=imagenet
# train on simple dataset, which is is same as datasets/nucleus but has only 50 stage1_train subfolders
# !python nucleus.py train --dataset=../../simple-dataset/nucleus --subset=train --weights=imagenet
# train on simple dataset, which is is same as datasets/nucleus but has only 300 stage1_train subfolders
# 25 val
# !python nucleus.py train --dataset=../../simple-300-images-dataset/nucleus --subset=train --weights=imagenet
# Out:
# Using TensorFlow backend.
# Weights:  imagenet
# Dataset:  ../../simple-300-images-dataset/nucleus
# Subset:  train
# Logs:  /content/drive/My Drive/data/summer-project/Mask_RCNN/logs
#
# Configurations:
# BACKBONE                       resnet50
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                